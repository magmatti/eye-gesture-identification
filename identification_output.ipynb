# %% [markdown]
# ### Imports

# %%
import re

import pandas as pd
from IPython.display import Markdown, display

from src.analyze import build_report_tables, run_analysis
from src.detection_config import DetectionConfig

# %% [markdown]
# ### Helper functions

# %%
def file_type(source_file: str) -> str:
    return re.sub(r"_\d{8}_\d{6}\.csv$", "", str(source_file))


def display_all_events_by_file_type(events: pd.DataFrame) -> None:
    events = events.copy()
    events["file_type"] = events["source_file"].map(file_type)

    for group_name, group in events.groupby("file_type", sort=True):
        display(Markdown(f"#### {group_name}"))
        display(group.drop(columns="file_type"))

# %% [markdown]
# ### Running analysis

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

events = run_analysis(DetectionConfig())

report_tables = build_report_tables(events)

# %% [markdown]
# ### Show data

# %%
for label, table in report_tables:
    display(Markdown(f"### {label}"))
    if label == "All events":
        display_all_events_by_file_type(table)
    else:
        display(table)
# Out:
# ### Event counts by file
# gesture                          filename  blink_count  fixation_count  \
# 0           BlinkData_20260609_112453.csv            5               0
# 1        FixationData_20260609_112242.csv            0              11
# 2        FixationData_20260609_112339.csv            0               2
# 3         SaccadeData_20260609_112413.csv            0               7
#
# gesture  saccade_count
# 0                    0
# 1                    4
# 2                    0
# 3                    4
# ### Event summary by file
#                         source_file  event_count total_duration_ms  \
# 0     BlinkData_20260609_112453.csv            5            1621.0
# 1  FixationData_20260609_112242.csv           15            8413.0
# 2  FixationData_20260609_112339.csv            2            9535.0
# 3   SaccadeData_20260609_112413.csv           11            7338.0
#
#   mean_duration_ms
# 0            324.2
# 1       560.866667
# 2           4767.5
# 3       667.090909
# ### Event summary by gesture
#     gesture  event_count total_duration_ms mean_duration_ms mean_peak_value
# 0     blink            5            1621.0            324.2        0.995166
# 1  fixation           20           24894.0           1244.7       12.982064
# 2   saccade            8             392.0             49.0      249.014276
# ### All events
# #### BlinkData
#                      source_file      phase gesture start_time_s end_time_s  \
# 0  BlinkData_20260609_112453.csv  recording   blink        2.538      3.031
# 1  BlinkData_20260609_112453.csv  recording   blink        4.088      4.278
# 2  BlinkData_20260609_112453.csv  recording   blink        5.456      5.614
# 3  BlinkData_20260609_112453.csv  recording   blink        7.007      7.418
# 4  BlinkData_20260609_112453.csv  recording   blink        8.598      8.967
#
#   duration_ms peak_value sample_count
# 0       493.0        1.0           45
# 1       190.0        1.0           18
# 2       158.0        1.0           15
# 3       411.0   0.988365           38
# 4       369.0   0.987465           34
# #### FixationData
#                          source_file      phase   gesture start_time_s  \
# 5   FixationData_20260609_112242.csv  recording  fixation        0.568
# 6   FixationData_20260609_112242.csv  recording  fixation         2.15
# 7   FixationData_20260609_112242.csv  recording  fixation        2.787
# 8   FixationData_20260609_112242.csv  recording   saccade          3.9
# 9   FixationData_20260609_112242.csv  recording  fixation          4.0
# 10  FixationData_20260609_112242.csv  recording  fixation         5.07
# 11  FixationData_20260609_112242.csv  recording   saccade        5.314
# 12  FixationData_20260609_112242.csv  recording   saccade        5.382
# 13  FixationData_20260609_112242.csv  recording   saccade        5.582
# 14  FixationData_20260609_112242.csv  recording  fixation        5.671
# 15  FixationData_20260609_112242.csv  recording  fixation        7.052
# 16  FixationData_20260609_112242.csv  recording  fixation         7.51
# 17  FixationData_20260609_112242.csv  recording  fixation        8.121
# 18  FixationData_20260609_112242.csv  recording  fixation        8.366
# 19  FixationData_20260609_112242.csv  recording  fixation        9.681
# 20  FixationData_20260609_112339.csv  recording  fixation        0.324
# 21  FixationData_20260609_112339.csv  recording  fixation        5.115
#
#    end_time_s duration_ms  peak_value sample_count
# 5       2.117      1549.0    9.359594          140
# 6       2.563       413.0   11.044981           38
# 7       3.867      1080.0    10.68635           98
# 8       3.978        78.0  241.654572            8
# 9       5.048      1048.0   13.433111           95
# 10      5.281       211.0    14.26151           20
# 11      5.337        23.0  167.718139            3
# 12      5.427        45.0  193.002564            5
# 13      5.661        79.0  427.363071            8
# 14      7.019      1348.0   12.969518          122
# 15      7.464       412.0   18.762181           38
# 16      8.032       522.0   12.994254           48
# 17        8.3       179.0   21.647782           17
# 18      9.636      1270.0   12.338331          115
# 19      9.837       156.0   14.681262           15
# 20       4.97      4646.0    9.730778          418
# 21     10.004      4889.0     8.73544          440
# #### SaccadeData
#                         source_file      phase   gesture start_time_s  \
# 22  SaccadeData_20260609_112413.csv  recording   saccade        2.318
# 23  SaccadeData_20260609_112413.csv  recording  fixation        2.385
# 24  SaccadeData_20260609_112413.csv  recording  fixation        2.952
# 25  SaccadeData_20260609_112413.csv  recording   saccade        4.278
# 26  SaccadeData_20260609_112413.csv  recording  fixation        4.356
# 27  SaccadeData_20260609_112413.csv  recording  fixation        4.834
# 28  SaccadeData_20260609_112413.csv  recording   saccade        6.294
# 29  SaccadeData_20260609_112413.csv  recording  fixation        6.372
# 30  SaccadeData_20260609_112413.csv  recording   saccade        8.263
# 31  SaccadeData_20260609_112413.csv  recording  fixation        8.319
# 32  SaccadeData_20260609_112413.csv  recording  fixation        8.487
#
#    end_time_s duration_ms  peak_value sample_count
# 22      2.362        44.0  262.917528            5
# 23      2.885       500.0   11.505905           46
# 24      4.256      1304.0   10.378748          118
# 25      4.323        45.0  240.495372            5
# 26      4.768       412.0   13.944778           38
# 27      6.272      1438.0    10.27145          130
# 28      6.338        44.0  253.254266            5
# 29      8.241      1869.0   12.086903          169
# 30      8.297        34.0  205.708691            4
# 31      8.453       134.0   18.493519           13
# 32     10.001      1514.0   12.314876          137
