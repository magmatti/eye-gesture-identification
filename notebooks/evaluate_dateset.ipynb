# %% [markdown]
# Rule-based eye gesture baseline
#
# This notebook loads the CSV files, runs the blink/fixation/saccade baseline detectors, and prints the trial-level report.

# %%
import sys
import pandas as pd

from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path('..').resolve()
SRC_DIR = PROJECT_ROOT / 'src'


if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

from pipeline import evaluate_dataset


report = evaluate_dataset()
report
# Out:
# Saved report to: /Users/mateuszwojtowicz/Developer/PK/MGR/kod_zrodlowy/eye-gesture-identification/reports/rule_based_results.csv
# Trial-level accuracy on current dataset: 1.000
#                        file_name expected_label predicted_label  correct
#    BlinkData_20260421_133939.csv          blink           blink     True
#    BlinkData_20260421_133954.csv          blink           blink     True
#    BlinkData_20260421_134021.csv          blink           blink     True
# FixationData_20260421_133403.csv       fixation        fixation     True
# FixationData_20260421_133657.csv       fixation        fixation     True
# FixationData_20260421_133712.csv       fixation        fixation     True
# FixationData_20260421_133740.csv       fixation        fixation     True
#  SaccadeData_20260421_133420.csv        saccade         saccade     True
#  SaccadeData_20260421_133436.csv        saccade         saccade     True
# ...
