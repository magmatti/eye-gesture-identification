# %% [markdown]
# Rule-based eye gesture baseline
#
# This notebook loads the latest CSV files, runs the baseline detectors, and prints the trial-level report.

# %%
import sys
import pandas as pd

from pathlib import Path

from eye_gesture_analysis.pipeline import evaluate_dataset


PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path('..').resolve()

print(PROJECT_ROOT)
SRC_DIR = PROJECT_ROOT / 'src'


if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))


report = evaluate_dataset()
report
